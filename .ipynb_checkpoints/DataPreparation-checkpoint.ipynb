# %%
# import libraries
import os 
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fastai.vision.all import *

# %%
# Each of these directories contain examples of different class
print(len(os.listdir("..\dataset")), os.listdir("..\dataset"))
# Out:
# 108 ['adho mukha svanasana', 'adho mukha vriksasana', 'agnistambhasana', 'ananda balasana', 'anantasana', 'anjaneyasana', 'ardha bhekasana', 'ardha chandrasana', 'ardha matsyendrasana', 'ardha pincha mayurasana', 'ardha uttanasana', 'ashtanga namaskara', 'astavakrasana', 'baddha konasana', 'bakasana', 'balasana', 'bhairavasana', 'bharadvajasana i', 'bhekasana', 'bhujangasana', 'bhujapidasana', 'bitilasana', 'camatkarasana', 'chakravakasana', 'chaturanga dandasana', 'dandasana', 'dhanurasana', 'durvasasana', 'dwi pada viparita dandasana', 'eka pada koundinyanasana i', 'eka pada koundinyanasana ii', 'eka pada rajakapotasana', 'eka pada rajakapotasana ii', 'ganda bherundasana', 'garbha pindasana', 'garudasana', 'gomukhasana', 'halasana', 'hanumanasana', 'janu sirsasana', 'kapotasana', 'krounchasana', 'kurmasana', 'lolasana', 'makara adho mukha svanasana', 'makarasana', 'malasana', 'marichyasana i', 'marichyasana iii', 'marjaryasana', 'matsyasana', 'mayurasana', 'models', 'natarajasana', 'padangusthasana', 'padmasana', 'parighasana', 'paripurna navasana', 'parivrtta janu sirsasana', 'parivrtta parsvakonasana', 'parivrtta trikonasana', 'parsva bakasana', 'parsvottanasana', 'pasasana', 'paschimottanasana', 'phalakasana', 'pincha mayurasana', 'prasarita padottanasana', 'purvottanasana', 'salabhasana', 'salamba bhujangasana', 'salamba sarvangasana', 'salamba sirsasana', 'savasana', 'setu bandha sarvangasana', 'simhasana', 'sukhasana', 'supta baddha konasana', 'supta matsyendrasana', 'supta padangusthasana', 'supta virasana', 'tadasana', 'tittibhasana', 'tolasana', 'tulasana', 'upavistha konasana', 'urdhva dhanurasana', 'urdhva hastasana', 'urdhva mukha svanasana', 'urdhva prasarita eka padasana', 'ustrasana', 'utkatasana', 'uttana shishosana', 'uttanasana', 'utthita ashwa sanchalanasana', 'utthita hasta padangustasana', 'utthita parsvakonasana', 'utthita trikonasana', 'vajrasana', 'vasisthasana', 'viparita karani', 'virabhadrasana i', 'virabhadrasana ii', 'virabhadrasana iii', 'virasana', 'vriksasana', 'vrischikasana', 'yoganidrasana']

# %%
# Lets see how many example we have for each class
d = {}
for c in os.listdir("..\dataset"):
    num = len(os.listdir("..\\dataset\\"+c))
    print(c,':', num)
    d[c]=num
# Out:
# adho mukha svanasana : 69
# adho mukha vriksasana : 59
# agnistambhasana : 33
# ananda balasana : 59
# anantasana : 43
# anjaneyasana : 64
# ardha bhekasana : 40
# ardha chandrasana : 52
# ardha matsyendrasana : 90
# ardha pincha mayurasana : 47
# ardha uttanasana : 66
# ashtanga namaskara : 34
# astavakrasana : 72
# baddha konasana : 70
# bakasana : 77
# balasana : 71
# bhairavasana : 46
# bharadvajasana i : 54
# bhekasana : 39
# bhujangasana : 73
# bhujapidasana : 61
# bitilasana : 87
# camatkarasana : 54
# chakravakasana : 70
# chaturanga dandasana : 90
# dandasana : 60
# dhanurasana : 46
# durvasasana : 39
# dwi pada viparita dandasana : 55
# eka pada koundinyanasana i : 51
# eka pada koundinyanasana ii : 58
# eka pada rajakapotasana : 44
# eka pada rajakapotasana ii : 55
# ganda bherundasana : 39
# garbha pindasana : 36
# garudasana : 78
# gomukhasana : 72
# halasana : 66
# hanumanasana : 35
# janu sirsasana : 48
# kapotasana : 57
# krounchasana : 45
# kurmasana : 40
# lolasana : 36
# makara adho mukha svanasana : 43
# makarasana : 57
# malasana : 68
# marichyasana i : 49
# marichyasana iii : 33
# marjaryasana : 46
# matsyasana : 57
# mayurasana : 51
# models : 0
# natarajasana : 72
# padangusthasana : 18
# padmasana : 68
# parighasana : 43
# paripurna navasana : 68
# parivrtta janu sirsasana : 39
# parivrtta parsvakonasana : 40
# parivrtta trikonasana : 62
# parsva bakasana : 56
# parsvottanasana : 35
# pasasana : 56
# paschimottanasana : 56
# phalakasana : 57
# pincha mayurasana : 35
# prasarita padottanasana : 66
# purvottanasana : 63
# salabhasana : 58
# salamba bhujangasana : 55
# salamba sarvangasana : 67
# salamba sirsasana : 60
# savasana : 57
# setu bandha sarvangasana : 58
# simhasana : 49
# sukhasana : 50
# supta baddha konasana : 71
# supta matsyendrasana : 54
# supta padangusthasana : 62
# supta virasana : 60
# tadasana : 56
# tittibhasana : 57
# tolasana : 60
# tulasana : 31
# upavistha konasana : 60
# urdhva dhanurasana : 68
# urdhva hastasana : 47
# urdhva mukha svanasana : 63
# urdhva prasarita eka padasana : 53
# ustrasana : 87
# utkatasana : 73
# uttana shishosana : 50
# uttanasana : 63
# utthita ashwa sanchalanasana : 38
# utthita hasta padangustasana : 59
# utthita parsvakonasana : 63
# utthita trikonasana : 69
# vajrasana : 54
# vasisthasana : 74
# viparita karani : 69
# virabhadrasana i : 55
# virabhadrasana ii : 56
# virabhadrasana iii : 61
# virasana : 50
# vriksasana : 62
# vrischikasana : 51
# yoganidrasana : 46

# %%
# make a barplot
names = list(d.keys())
values = list(d.values())


fig, ax = plt.subplots(figsize =(16, 50))
 
# Horizontal Bar Plot
ax.barh(names, values)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')


# Add Plot Title
ax.set_title('Classnames and number of trainin',
             loc ='left', )
# Out:
# C:\Users\ritap\AppData\Local\Temp\ipykernel_3040\4004388534.py:24: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b = True, color ='grey',
# Text(0.0, 1.0, 'Classnames and number of trainin')

# %%
base_path = "E:\\Work\Data_Science\\Projects\\Image_Classification_FastAI_V2\\dataset"
data = pd.DataFrame(columns=['image_name', 'label'])

image_names = []
labels = []
for c in os.listdir("..\dataset"):
    for i in os.listdir("..\\dataset\\"+c):
        image_names.append(c+"\\"+i)
        labels.append(c)
data['image_name'] = image_names
data['label'] = labels

# %%
data
# Out:
#                                                                                                             image_name  \
# 0                                                                                        adho mukha svanasana\1. 1.png
# 1                                                   adho mukha svanasana\1. 5-benefits-of-downward-facing-dog-pose.png
# 2                                             adho mukha svanasana\10. screen-shot-2017-09-15-at-17.00.06-1024x585.png
# 3     adho mukha svanasana\11. yoga_anatomy_using_muscle_awareness_to_lower_your_heels_in_downward_facing_dog_pose.png
# 4                                                        adho mukha svanasana\12. 66a62b8c606fd88e0401b5af0a7cbca7.png
# ...                                                                                                                ...
# 5989                                                                                            yoganidrasana\86-0.png
# 5990                                                                                            yoganidrasana\87-0.png
# 5991                                                                                             yoganidrasana\9-0.png
# 5992                                                                                            yoganidrasana\91-1.png
# 5993                                                                                            yoganidrasana\97-0.png
#
#                      label
# 0     adho mukha svanasana
# 1     adho mukha svanasana
# 2     adho mukha svanasana
# 3     adho mukha svanasana
# 4     adho mukha svanasana
# ...                    ...
# 5989         yoganidrasana
# 5990         yoganidrasana
# 5991         yoganidrasana
# 5992         yoganidrasana
# 5993         yoganidrasana
#
# [5994 rows x 2 columns]

# %%
# Split train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data['image_name'], data['label'], test_size=0.2, stratify=data['label'], random_state=12345)

# %%
X_train
# Out:
# 3537                   phalakasana\46-0.png
# 3380               parsvottanasana\69-0.png
# 104          adho mukha vriksasana\62-0.png
# 1822    eka pada koundinyanasana ii\9-0.png
# 1120                  bhujangasana\56-0.png
#                        ...
# 725                  astavakrasana\96-1.png
# 3842          salamba sarvangasana\19-0.png
# 5164                    uttanasana\65-0.png
# 5733            virabhadrasana iii\18-0.png
# 467           ardha matsyendrasana\58-0.png
# Name: image_name, Length: 4795, dtype: object

# %%
y_train
# Out:
# 3537                    phalakasana
# 3380                parsvottanasana
# 104           adho mukha vriksasana
# 1822    eka pada koundinyanasana ii
# 1120                   bhujangasana
#                    ...
# 725                   astavakrasana
# 3842           salamba sarvangasana
# 5164                     uttanasana
# 5733             virabhadrasana iii
# 467            ardha matsyendrasana
# Name: label, Length: 4795, dtype: object

# %%
# Make and save training data
train_data = pd.DataFrame()
train_data['image_name'] = X_train
train_data['label'] = y_train
train_data.to_csv(r"..\train_data.csv", index=False)

# %%
# Make and save test data
test_data = pd.DataFrame()
test_data['image_name'] = X_test
test_data['label'] = y_test
test_data.to_csv(r"..\test_data.csv", index=False)

# %%
train_data = pd.read_csv(r"..\train_data.csv")
train_data
# Out:
#                                image_name                        label
# 0                    phalakasana\46-0.png                  phalakasana
# 1                parsvottanasana\69-0.png              parsvottanasana
# 2          adho mukha vriksasana\62-0.png        adho mukha vriksasana
# 3     eka pada koundinyanasana ii\9-0.png  eka pada koundinyanasana ii
# 4                   bhujangasana\56-0.png                 bhujangasana
# ...                                   ...                          ...
# 4790               astavakrasana\96-1.png                astavakrasana
# 4791        salamba sarvangasana\19-0.png         salamba sarvangasana
# 4792                  uttanasana\65-0.png                   uttanasana
# 4793          virabhadrasana iii\18-0.png           virabhadrasana iii
# 4794        ardha matsyendrasana\58-0.png         ardha matsyendrasana
#
# [4795 rows x 2 columns]

# %%
# Prepare fastai training data

fastai_vision_classifier_data = (
    ImageDataLoaders.from_df(
        path=base_path,
        df=train_data,
        valid_pct=0.3,
        random_seed=123456,
        fn_col="image_name",
        label_col="label",
        size=224,
        item_tfms=Resize(200),
        ds_tfms=RandTransform() #for data augmentation
    )
)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
fastai_vision_classifier_data.show_batch()

# %%
torch.save(fastai_vision_classifier_data, "../fastai_data/fastai_vision_classifier_data.pkl")
